# %%
pip install nltk scikit-learn streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing necessary libraries
import nltk
import random
import os
import ssl
import streamlit as st
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
ssl._create_default_https_context = ssl._create_unverified_context
nltk.data.path.append(os.path.abspath('nltk_data'))
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\krush\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
intents = [
    {
        "tag": "greeting",
        "patterns": ["Hello", "Hi", "Hey"],
        "responses": ["Hello!", "Hi there!", "Hey!", "Good to see you!"]
    },
    {
        "tag": "greet",
        "patterns": ["How are you?", "What's up?"],
        "responses": ["I'm good, how about you?", "It's good, what about you"]
    },
     {
        "tag": "age",
        "patterns": ["what is your age", "How old are you", "age"],
        "responses": ["I don't have an age. I'm a chatbot.", "I was just born in the digital world.", "Age is just a number for me."]
    },
    {
        "tag": "goodbye",
        "patterns": ["Goodbye", "See you later", "Bye", "Take care"],
        "responses": ["Goodbye!", "See you soon!", "Take care!", "Have a great day!"]
    },
    {
        "tag": "thanks",
        "patterns": ["Thank you", "Thanks", "I appreciate it", "Thanks a lot"],
        "responses": ["You're welcome!", "No problem!", "Glad to help!", "Anytime!"]
    },
    {
        "tag": "about",
        "patterns": ["Who are you?", "What can you do?", "Tell me about yourself"],
        "responses": ["I am a chatbot designed to assist you.", "I can answer your questions and help with various topics."]
    },
    {
        "tag": "study_tips",
        "patterns": ["How to study effectively?", "Best study techniques?", "How can I focus on studying?"],
        "responses": [
            "Use the Pomodoro technique: 25 minutes study, 5 minutes break.",
            "Create a study schedule and stick to it.",
            "Avoid distractions and keep your study area clean."
        ]
    },
    {
        "tag": "exam_preparation",
        "patterns": ["How to prepare for exams?", "Best revision techniques?", "How can I do well in exams?"],
        "responses": [
            "Revise regularly and practice previous year papers.",
            "Break down large topics into smaller sections.",
            "Stay calm, take breaks, and get enough sleep before exams."
        ]
    },
    {
        "tag": "competitive_exams",
        "patterns": ["Best way to prepare for UPSC?", "JEE preparation tips?", "How to crack NEET?"],
        "responses": [
            "UPSC: Read NCERT books and follow current affairs daily.",
            "JEE: Focus on Physics, Chemistry, and Mathematics with regular practice.",
            "NEET: Revise Biology NCERT thoroughly and practice mock tests."
        ]
    },
    {
        "tag": "college_admissions",
        "patterns": ["Top engineering colleges in India?", "Best medical colleges?", "How to get into IIT?"],
        "responses": [
            "Top engineering colleges: IITs, NITs, BITS Pilani, IIITs.",
            "Best medical colleges: AIIMS, JIPMER, CMC Vellore.",
            "For IIT admission, you need to clear JEE Advanced."
        ]
    },
    {
        "tag": "online_courses",
        "patterns": ["Best websites for online learning?", "Where can I learn coding for free?", "Skill development platforms?"],
        "responses": [
            "You can learn from Coursera, Udemy, edX, and Khan Academy.",
            "Free coding courses: freeCodeCamp, GeeksforGeeks, W3Schools, CodeWithHarry.",
            "Skill development: LinkedIn Learning, Skillshare, NPTEL."
        ]
    },
    {
        "tag": "budgeting",
        "patterns": ["How to make a budget?", "Best budgeting strategies?", "How to save money?"],
        "responses": [
            "Track your income and expenses to understand your spending habits.",
            "Use the 50/30/20 rule: 50% essentials, 30% wants, 20% savings.",
            "Set financial goals and stick to them."
        ]
    },
    {
        "tag": "credit_score",
        "patterns": ["What is a credit score?", "How to improve my credit score?", "Where can I check my credit score?"],
        "responses": [
            "A credit score is a number representing your creditworthiness.",
            "Improve your credit score by paying bills on time and maintaining a low credit utilization ratio.",
            "Check your credit score on sites like Credit Karma and CIBIL."
        ]
    },
    {
        "tag": "investment",
        "patterns": ["Best investment options in India?", "How to start investing?", "What is mutual fund investment?"],
        "responses": [
            "Popular investment options: Stocks, Mutual Funds, Fixed Deposits, Real Estate.",
            "Start investing by setting financial goals and researching investment options.",
            "Mutual funds pool money from investors to invest in stocks, bonds, and other assets."
        ]
    },
    {
        "tag": "technology",
        "patterns": ["Latest tech trends?", "What is AI?", "How does blockchain work?"],
        "responses": [
            "AI is a technology that enables machines to learn and make decisions.",
            "Blockchain is a decentralized digital ledger used for secure transactions.",
            "Tech trends: AI, IoT, Metaverse, Quantum Computing."
        ]
    },
    {
        "tag": "health",
        "patterns": ["How to stay healthy?", "Best diet tips?", "How to boost immunity?"],
        "responses": [
            "Eat a balanced diet with fruits, vegetables, and proteins.",
            "Exercise regularly and get enough sleep.",
            "Stay hydrated and practice stress management techniques."
        ]
    },
    {
        "tag": "exercise",
        "patterns": ["Best exercises for weight loss?", "How to stay fit?", "What is the best workout routine?"],
        "responses": [
            "For weight loss: Cardio, HIIT, and strength training work best.",
            "To stay fit: Exercise daily and maintain a healthy diet.",
            "A balanced workout routine includes strength, cardio, and flexibility exercises."
        ]
    },
    {
        "tag": "mental_health",
        "patterns": ["How to reduce stress?", "Ways to improve mental health?", "What are relaxation techniques?"],
        "responses": [
            "Practice meditation and deep breathing exercises.",
            "Engage in hobbies and activities you enjoy.",
            "Talk to someone if you're feeling overwhelmed."
        ]
    },
    {
        "tag": "bollywood",
        "patterns": ["Best Bollywood movies?", "Top Indian actors?", "Latest Bollywood releases?"],
        "responses": [
            "Best Bollywood movies: DDLJ, Sholay, 3 Idiots, ZNMD.",
            "Top actors: Shah Rukh Khan, Amitabh Bachchan, Deepika Padukone, Alia Bhatt.",
            "Check BookMyShow or IMDb for latest releases."
        ]
    },
    {
        "tag": "cricket",
       "patterns": ["Latest cricket news?", "Who won the match today?", "Best Indian cricketers?"],
        "responses": [
            "For live scores, check ESPN or Cricbuzz.",
            "Best cricketers: Sachin Tendulkar, Virat Kohli, MS Dhoni, Rohit Sharma.",
            "India's biggest cricket tournaments: IPL, Ranji Trophy, World Cup."
        ]
    },
    {
        "tag": "government_schemes",
        "patterns": ["Latest government schemes?", "Modi's schemes?", "Government startup support?"],
        "responses": [
            "Popular schemes: PM Kisan, Ayushman Bharat, Digital India.",
            "Startup India and Standup India support new businesses.",
            "Swachh Bharat Abhiyan focuses on cleanliness and sanitation."
        ]
    },
     
    {
        "tag": "indian_travel",
        "patterns": ["Best places to visit in India?", "Famous tourist destinations?", "Honeymoon places in India?"],
        "responses": [
            "Best travel spots: Taj Mahal, Jaipur, Kerala, Goa, Ladakh.",
            "For nature lovers: Himachal Pradesh, Uttarakhand, Northeast India.",
            "Top honeymoon destinations: Kashmir, Andaman & Nicobar, Udaipur."
        ]
    }
]

# %%
# Create the vectorizer and classifier
vectorizer = TfidfVectorizer()
clf = LogisticRegression(random_state=0, max_iter=10000)

#Preprocess the data
tags = []
patterns = []
for intent in intents:
    for pattern in intent['patterns']:
        tags.append(intent['tag'])
        patterns.append(pattern)

# %%
# Training the model
x = vectorizer.fit_transform(patterns)
y = tags
clf.fit(x, y)
# Out:
# LogisticRegression(max_iter=10000, random_state=0)

# %%
# Python function to chat with the chatbot
def chatbot(input_text):
    input_text = vectorizer.transform([input_text])
    tag = clf.predict(input_text)[0]
    for intent in intents:
        if intent['tag'] == tag:
            response = random.choice(intent['responses'])
            return response

# %%
# Checking our chatbot.
user_input= input("Enter something: ")
#user_input = "Hello"
response = chatbot(user_input)
print(response)
# Out:
# Enter something:  hello
# Hi there!

# %%
user_input = "age"
response = chatbot(user_input)
print(response)
# Out:
# Have a great day!
